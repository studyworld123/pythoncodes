# %%
import pandas as pd

# %%
data=pd.read_csv("/home/palcement/Downloads/fiat500.csv")

# %%
data1=data.loc[data.km>=50000]

# %%
data1
# Out:
#         ID   model  engine_power  age_in_days      km  previous_owners  \
# 2        3   sport            74         4658  142228                1
# 3        4  lounge            51         2739  160000                1
# 4        5     pop            73         3074  106880                1
# 5        6     pop            74         3623   70225                1
# 8        9   sport            73         4049   76000                1
# ...    ...     ...           ...          ...     ...              ...
# 1533  1534   sport            51         3712  115280                1
# 1534  1535  lounge            74         3835  112000                1
# 1535  1536     pop            51         2223   60457                1
# 1536  1537  lounge            51         2557   80750                1
# 1537  1538     pop            51         1766   54276                1
#
#             lat        lon  price
# 2     45.503300  11.417840   4200
# 3     40.633171  17.634609   6000
# ...

# %%
data2=data.loc[data.km<=50000]

# %%
data2
# Out:
#         ID   model  engine_power  age_in_days     km  previous_owners  \
# 0        1  lounge            51          882  25000                1
# 1        2     pop            51         1186  32500                1
# 6        7  lounge            51          731  11600                1
# 7        8  lounge            51         1521  49076                1
# 10      11     pop            51          790  43286                1
# ...    ...     ...           ...          ...    ...              ...
# 1525  1526  lounge            51          790  41870                1
# 1526  1527  lounge            51         1705  23600                1
# 1527  1528     pop            51          517   3000                1
# 1529  1530  lounge            51          731  22551                1
# 1530  1531  lounge            51          670  29000                1
#
#             lat       lon  price
# 0     44.907242   8.61156   8900
# 1     45.666359  12.24189   8800
# ...

# %%
data2.groupby(['model']).count()
# Out:
#          ID  engine_power  age_in_days   km  previous_owners  lat  lon  price
# model
# lounge  734           734          734  734              734  734  734    734
# pop     162           162          162  162              162  162  162    162
# sport    11            11           11   11               11   11   11     11

# %%
data2=data2.rename(columns={'engine_power':'engine'})

# %%
data2
# Out:
#         ID   model  engine  age_in_days     km  previous_owners        lat  \
# 0        1  lounge      51          882  25000                1  44.907242
# 1        2     pop      51         1186  32500                1  45.666359
# 6        7  lounge      51          731  11600                1  44.907242
# 7        8  lounge      51         1521  49076                1  41.903221
# 10      11     pop      51          790  43286                1  40.871429
# ...    ...     ...     ...          ...    ...              ...        ...
# 1525  1526  lounge      51          790  41870                1  45.707249
# 1526  1527  lounge      51         1705  23600                1  38.122070
# 1527  1528     pop      51          517   3000                1  40.748241
# 1529  1530  lounge      51          731  22551                1  38.122070
# 1530  1531  lounge      51          670  29000                1  45.764648
#
#            lon  price
# 0      8.61156   8900
# ...

# %%
list(data2)
# Out:
# ['ID',
#  'model',
#  'engine',
#  'age_in_days',
#  'km',
#  'previous_owners',
#  'lat',
#  'lon',
#  'price']

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('movies.csv')
df.plot()
# plt.show()
# Out:
# <Axes: >

# %%
# data.groupby(['model']).count()

# %%
data.drop(['model'],axis=1)
# Out:
#         ID  engine_power  age_in_days      km  previous_owners        lat  \
# 0        1            51          882   25000                1  44.907242
# 1        2            51         1186   32500                1  45.666359
# 2        3            74         4658  142228                1  45.503300
# 3        4            51         2739  160000                1  40.633171
# 4        5            73         3074  106880                1  41.903221
# ...    ...           ...          ...     ...              ...        ...
# 1533  1534            51         3712  115280                1  45.069679
# 1534  1535            74         3835  112000                1  45.845692
# 1535  1536            51         2223   60457                1  45.481541
# 1536  1537            51         2557   80750                1  45.000702
# 1537  1538            51         1766   54276                1  40.323410
#
#             lon  price
# 0      8.611560   8900
# 1     12.241890   8800
# ...

# %%
data1=pd.read_csv("/home/palcement/Downloads/fiat500.csv")

# %% [markdown]
# data1

# %%
data1
# Out:
#         ID   model  engine_power  age_in_days      km  previous_owners  \
# 0        1  lounge            51          882   25000                1
# 1        2     pop            51         1186   32500                1
# 2        3   sport            74         4658  142228                1
# 3        4  lounge            51         2739  160000                1
# 4        5     pop            73         3074  106880                1
# ...    ...     ...           ...          ...     ...              ...
# 1533  1534   sport            51         3712  115280                1
# 1534  1535  lounge            74         3835  112000                1
# 1535  1536     pop            51         2223   60457                1
# 1536  1537  lounge            51         2557   80750                1
# 1537  1538     pop            51         1766   54276                1
#
#             lat        lon  price
# 0     44.907242   8.611560   8900
# 1     45.666359  12.241890   8800
# ...
